# %% [markdown]
# #Functions
# Blocks of code that perform a particular task.
# To perform the task, you have to `call` the name of the function.

# %%
"""
Name of the function. 
"""
def greet_people():
  print("Good morning")

greet_people()

# %%
ilist=[20,54,2,8,87,96,35,15]
def par(nlist,low,high):
    pivot=nlist[low]
    i=low+1
    for j in range(low+1,high+1):
      if nlist[j] < pivot:
         nlist[j],nlist[i]=nlist[i],nlist[j]
         i+=1
    nlist[low],nlist[i-1]=nlist[i-1],nlist[low]
    return nlist,i
ilist,k=par(ilist,0,7)
def qs'e
# Out:
# [15, 2, 8, 20, 87, 96, 35, 54]

# %%
# Passing information to the function

def greet_people(person):
  print("Hello", person.lower())

greet_people("Subhankar")

# The value "Subhankar" is the argument and person variable would be the parameter.

# %%
# Write a function that returns count number of digits of input number. 

def countdigits(num):
  count = 0
  while num != 0:
    num = int(num/10)
    count = count + 1
  return count

print(countdigits(2210))


def countdigits(num):
  if num == 0:
    return 0
  return 1 + countdigits(int(num/10))

print(countdigits(2210))


# Write a function that returns the sum of the input number.

# %%
print('enter the number of elements to sort')
n=int(input())
numlit=[]
print('enter the values followed by enter : ')
for i in range(0,n):
  numlit.append(int(input()))
j=1
l=1
for i in range(0,n/2):
  for k in range(0,n):
# Out:
# enter the number of elements to sort
# 5
# enter the values followed by enter :
# 52
# 42
# 32
# 22
# 12
# [52, 42, 32, 22, 12]

# %%
def function(x,y):
    sum=0
    c=0
    for i in range(x,y+1):
       sum=sum+i
       c=c+1
    avg=sum/c
    return sum,avg 
sn=int(input("enter the start number: "))
en=int(input("enter the end number: "))
print("the sum and average respectively are" ,function(sn,en))
# Out:
# enter the start number: 2
# enter the end number: 8
# the sum and average respectively are (35, 5.0)

# %%
print("*")
# Out:
# *

# %%
#@title
def printer():
    n=int(input("enter the number of starts you want "))

    for j in range(1,n+1):
        print("")

        for i in range(1,n+1):
            print("*",end=(' '))
printer()
# Out:
# enter the number of starts you want 4
#
# * * * *
# * * * *
# * * * *
# * * * *

# %%
#@title
def printer():
    n=int(input("enter the number of starts you want "))

    for j in range(1,n+1):
        print("")

        for i in range(1,j+1):
            print("*",end=(' '))
printer()
# Out:
# enter the number of starts you want 4
#
# *
# * *
# * * *
# * * * *

# %%
xlist=[]
ylist=[]
for i in range(0,7):
  xlist.append(float(input()))
for i in range(0,7):
  ylist.append(float(input()))
sx=0
sy=0
for i in range(0,7):
  sx=sx+xlist[i]
for i in range(0,7):
  sy=sy+ylist[i]
print("sumx",sx)
print("sumy",sy)
xy=0
sxy=0
for i in range(0,7):
  xy=xlist[i]*ylist[i]
  sxy=sxy+xy
  print("xiyi",xy)
print("sumxy",sxy)
sumoxs=0
for i in range(0,7):
  xs=xlist[i]*xlist[i]
  sumoxs=sumoxs+xs
  print("xis",xs)
print(sumoxs)
s=((7*sxy)-(sx*sy))/((7*sumoxs)-(sx*sx))
print(s)
xb=sx/7
yb=sy/7
print(xb)
print(yb)
c=yb-(s*xb)
print(c)
# Out:
# 5.16
# 4.72
# 4
# 3.08
# 2.87
# 2.60
# 1.92
# 1.525
# 1.541
# 1.549
# 1.559
# 1.566
# 1.575
# 1.583
# sumx 24.35
# sumy 10.898
# xiyi 7.869
# xiyi 7.2735199999999995
# xiyi 6.196
# xiyi 4.8017199999999995
# xiyi 4.494420000000001
# xiyi 4.095
# xiyi 3.03936
# sumxy 37.769020000000005
# xis 26.625600000000002
# xis 22.278399999999998
# xis 16.0
# xis 9.4864
# xis 8.2369
# xis 6.760000000000001
# xis 3.6864
# 93.07370000000002
# -0.0167793642287356
# 3.4785714285714286
# 1.5568571428571427
# 1.615225359852816

# %%
listnum=[]
n=int(input('enter how many numbers you wanna arrange '))
print("keep on entering the numbers,press enter after each number")
for i in range(0,n):
  print("shhhh")
  listnum.append(int(input()))
for i in range(0,len(listnum)):
  for j in range(0,len(listnum)-1):
      if(listnum[j]>listnum[j+1]):
        listnum[j],listnum[j+1]=listnum[j+1],listnum[j]
print(listnum)
# Out:
# enter how many numbers you wanna arrange 4
# keep on entering the numbers,press enter after each number
# shhhh12
# 12
# shhhh12
# 15
# shhhh12
# 16
# shhhh12
# 13
# [12, 13, 15, 16]

# %% [markdown]
# ##Exercise 2.1
# 1. Write a function that returns kth largest element in a list.
# 2. Write a function that returns kth smallest element of an array.
# 3. Write a function to find maximum between three numbers.
# 4. Write a function to check whether a year is leap year or not.
# 5. Write a function to find first and last digit of any number.
# 6. Write a function to swap first and last digits of any number​.

# %%
'''
Ask the user for a number. 
Find all the even and odd numbers in between
1 to "number". 

Define a function that separates the numbers into 2 lists and returns the 2 lists. 

Print individual lists returned from the function. 
'''


def oddevenlist(tillrange):
  # create an odd list
  oddlist = []
  # create an even list
  evenlist = []

  # populate the lists with even and odd numbers
  # loop through all the numbers
  for number in range(1,tillrange): 
    # if number is even or if it is divisble by 2  
    if number%2 == 0:
      # then put into even list
      evenlist.append(number)
    # if number is odd or else
    else:
      # then put into odd list
      oddlist.append(number)
  return oddlist, evenlist

tillrange = 11
ioddlist, ievenlist = oddevenlist(tillrange)
print(ioddlist)
print(ievenlist)

# %% [markdown]
# ##Exercise 2.2
#
# 1. Ask the user for 2 numbers. Write a function that takes 2 numbers as input and returns LCM and HCF back.  Use the above function to try on some numbers as example.

# %% [markdown]
# #Classes
# - Object oriented programming is one of the approach. (Others include Functional programming).

# %%
# Creating a simple class

class Student:
  
  def __init__(self, name, age):
    # Special method, that is invoked whenever a new instance is created. 
    """
    The self parameter is required in the method definition, and it must 
    come first before the other parameters. It must be included in the 
    definition because when Python calls this __init__() method later 
    (to create an instance of Dog), the method call will automatically 
    pass the self argument. Every method call associated with a class 
    automatically passes self, which is a reference to the instance itself; 
    it gives the individual instance access to the attributes and methods 
    in the class.
    # Eric Matthes - Python Crash Course
    """
    self.name = name
    self.age = age
  
  
  def printInfo(self):
    print("Student name is ", self.name, "and age is ", self.age)
  
  def yearstohundred(self):
    print(self.name, "has ", 100-self.age, "years to become 100.")

# %%
class node:
    def __init__(self,d):
        self.data=d
        self.next=None
objectn = node(2)
print(objectn.data)
# Out:
# 2

# %%
class node:
    def __init__(self,d)
    self.data = d
    self.next=None
class ll:
    def init(self):
        self.head=None
    def insert(self,d):
        temp=node(d)
        temp.next=self.head
        self.head=temp

# %%
# Making an instance of class
subhankar = Student('Subhankar', 10)

# %%
# Accessing methods
subhankar.printInfo()
# Out:
# Student name is  Subhankar and age is  10

# %%
# Accessing attributes 
print(subhankar.name)
# Out:
# Subhankar

# %%
mishra = Student('Mishra', 20)
mishra.printInfo()
mishra.yearstohundred()
# Out:
# Student name is  Mishra and age is  20
# Mishra has  80 years to become 100.

# %% [markdown]
# ##Exercise
# 1. Change
#   1. Add >= 2 more useful attributes to the Student class.
#   1. Add >= 2 more useful method using the above attributes to the Student class.
#   1. Create instances and use them to call the methods.

# %% [markdown]
# #Things that are not covered but take a look (not required for the semester)
# 1. Inheritance
# 1. Import (importing methods and classes)
