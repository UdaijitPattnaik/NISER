# %%
class Node:
  def __init__(self,val):
    self.val=val
    self.next=None

class creat_ll:

  def __init__(self):
    self.head=None

  def insert_beg(self, val):
    temp = Node(val)
    temp.next = self.head
    self.head = temp

  def insert_end(self,val):
    temp=Node(val)
    curr=self.head
    while curr.next != None:
      curr=curr.next
    curr.next=temp
    temp.next=None
  
  def insert_k(self,val,k):
    if k == 1:
      Clinklist1.insert_begin(val)
      return
    temp=Node(val)
    i=1
    curr=self.head
    while i != (k-1):
      curr=curr.next
      i=i+1
    temp.next=curr.next
    curr.next=temp

  def del_k(self,k):
    curr=self.head
    i=1
    while i != k-1:
      curr=curr.next
      i=i+1
    temp=curr.next
    curr.next=temp.next

  def print_ll(self):
    curr = self.head
    while curr != None:
      print(curr.val,"->",end="")
      curr = curr.next
    print("None")

linklist1=creat_ll()
n=int(input('enter first value: '))
linklist1.insert_beg(n)
linklist1.print_ll()
print(' enter b to add elements at the beginning of the list \n enter e to add element at the end of the list \n enter k to add element at any position of the list \n enter stop to stop adding elements to the list')
while True:
  o=input()
  if o == 'stop':
    break
  if o == 'b':
    n=int(input('enter the data: '))
   
  
  if o == 'e':
    n=int(input('enter the data: '))
    linklist1.insert_end(n)
  if o == 'k':
    n=int(input('enter the data: '))
    k=int(input('enter the position: '))
    linklist1.insert_k(n,k)
linklist1.print_ll()
# Out:
# enter first value: 1
# 1 ->None
#  enter b to add elements at the beginning of the list
#  enter e to add element at the end of the list
#  enter k to add element at any position of the list
#  enter stop to stop adding elements to the list
# b
# enter the data: 0
