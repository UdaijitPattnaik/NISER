# %%
def insert_root(self,val):
 
  if self.root == None:
    self.root= node(val)
  else:
    insert(val,self.root)

def insert(self,val,curr):

  if val >= curr.data:
    if curr.right == None:
      curr.right = node(val)
    else:
      insert(val,curr.right)
  else:
    if curr.left == None:
      curr.left= Node(val)
    else:
      insert(val,curr.left)
