# %%
#assuming the link list already exists and i only have to sort it
def sort(self)
  curr= self.head
  j=1
  while curr.next is not None:
      curr=curr.next
      j=j+1
  for i in range(0,j):
      c1=self.head
      c2=c1.next
      for k in range(0,j-1):
        if c1.data > c2data:
            v=c1.data
            c1.data=c2.data
            c2.data=v
        c1=c1.next
        c2=c2.next
